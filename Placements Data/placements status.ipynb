# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('placedata v2.0 synthetic.csv')

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_col = LabelEncoder()

# %%
df['n_ExtracurricularActivities'] = le_col.fit_transform(df['ExtracurricularActivities'])

# %%
df['n_PlacementTraining'] = le_col.fit_transform(df['PlacementTraining'])

# %%
df['n_PlacementStatus'] = le_col.fit_transform(df['PlacementStatus'])

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.corr()['n_PlacementStatus']
# Out:
# StudentID                      0.004294
# CGPA                           0.423131
# Internships                    0.260340
# Projects                       0.475186
# Workshops/Certifications       0.362268
# AptitudeTestScore              0.521744
# SoftSkillsRating               0.427284
# SSC_Marks                      0.469763
# HSC_Marks                      0.505746
# n_ExtracurricularActivities    0.482491
# n_PlacementTraining            0.323659
# n_PlacementStatus              1.000000
# Name: n_PlacementStatus, dtype: float64

# %%
df.drop(columns=['StudentID'], inplace = True)

# %%
df
# Out:
#       CGPA  Internships  Projects  Workshops/Certifications  \
# 0      7.5            1         1                         1
# 1      8.9            0         3                         2
# 2      7.3            1         2                         2
# 3      7.5            1         1                         2
# 4      8.3            1         2                         2
# ...    ...          ...       ...                       ...
# 9995   7.5            1         1                         2
# 9996   7.4            0         1                         0
# 9997   8.4            1         3                         0
# 9998   8.9            0         3                         2
# 9999   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                    65               4.4                        No
# 1                    90               4.0                       Yes
# ...

# %%
sns.barplot(x=df['CGPA'],y=df['n_PlacementStatus'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.boxplot(x=df["CGPA"])
# Out:
# <AxesSubplot: xlabel='CGPA'>

# %%
sns.boxplot(x=df["AptitudeTestScore"])
# Out:
# <AxesSubplot: xlabel='AptitudeTestScore'>

# %%
sns.boxplot(x=df['SoftSkillsRating'])
# Out:
# <AxesSubplot: xlabel='SoftSkillsRating'>

# %%
sns.barplot(x=df['AptitudeTestScore'],y=df['n_ExtracurricularActivities'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#       CGPA  Internships  Projects  Workshops/Certifications  \
# 0      7.5            1         1                         1
# 1      8.9            0         3                         2
# 2      7.3            1         2                         2
# 3      7.5            1         1                         2
# 4      8.3            1         2                         2
# ...    ...          ...       ...                       ...
# 9995   7.5            1         1                         2
# 9996   7.4            0         1                         0
# 9997   8.4            1         3                         0
# 9998   8.9            0         3                         2
# 9999   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                    65               4.4                        No
# 1                    90               4.0                       Yes
# ...

# %%
sns.barplot(x=df['SoftSkillsRating'],y=df['n_ExtracurricularActivities'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['SSC_Marks'],y=df['n_ExtracurricularActivities'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['HSC_Marks'],y=df['n_ExtracurricularActivities'])
plt.xticks(rotation='vertical')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
x = df.drop(['ExtracurricularActivities','PlacementTraining','PlacementStatus','n_PlacementStatus'], axis= 'columns')

# %%
y = df['n_PlacementStatus']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       CGPA  Internships  Projects  Workshops/Certifications  \
# 6674   7.6            1         1                         1
# 6212   7.7            1         3                         0
# 486    8.3            1         3                         1
# 6080   8.9            2         3                         2
# 8428   6.9            1         1                         1
# ...    ...          ...       ...                       ...
# 1256   7.6            1         1                         1
# 684    7.0            1         2                         0
# 6180   8.7            1         2                         1
# 5408   7.9            1         3                         0
# 2569   8.4            1         3                         2
#
#       AptitudeTestScore  SoftSkillsRating  SSC_Marks  HSC_Marks  \
# 6674                 70               4.4         55         70
# 6212                 89               4.6         80         83
# ...

# %%
y_train
# Out:
# 6674    0
# 6212    1
# 486     0
# 6080    1
# 8428    0
#        ..
# 1256    0
# 684     0
# 6180    1
# 5408    1
# 2569    1
# Name: n_PlacementStatus, Length: 8000, dtype: int32

# %%
x_test
# Out:
#       CGPA  Internships  Projects  Workshops/Certifications  \
# 4475   7.9            1         1                         1
# 2786   6.8            1         3                         2
# 978    7.5            1         1                         0
# 3918   8.4            0         3                         2
# 8337   7.5            1         1                         1
# ...    ...          ...       ...                       ...
# 5487   8.3            2         3                         2
# 2296   7.6            1         2                         0
# 4177   7.4            0         3                         2
# 2058   8.7            2         3                         2
# 6226   6.6            1         1                         2
#
#       AptitudeTestScore  SoftSkillsRating  SSC_Marks  HSC_Marks  \
# 4475                 79               4.0         55         61
# 2786                 83               4.7         64         80
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(LogisticRegression(max_iter=10000,tol=0.000001),x_train,y_train)
# Out:
# array([0.783125, 0.8     , 0.803125, 0.79625 , 0.8     ])

# %%
cross_val_score(SVC(),x_train,y_train)
# Out:
# array([0.776875, 0.775   , 0.793125, 0.779375, 0.790625])

# %%
cross_val_score(RandomForestClassifier(n_estimators=50),x_train,y_train)
# Out:
# array([0.7725  , 0.7775  , 0.780625, 0.781875, 0.78125 ])

# %%
model = LogisticRegression(max_iter=1000000000,tol=0.0000000000001)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000000000, tol=1e-13)

# %%
model.score(x_test,y_test)
# Out:
# 0.806

# %%
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)

# %%
cm
# Out:
# array([[990, 187],
#        [201, 622]], dtype=int64)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True)
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
